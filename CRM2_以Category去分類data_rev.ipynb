# %%
import numpy as np 
import pandas as pd 
import os

# %%
dir_path1 = '../google_data/1清洗資料/'
dir_path2 = '../google_data/資料/'

# %%
data_path1 = os.path.join(dir_path1, '清洗後review data.csv')
data_rev = pd.read_csv(data_path1)
print(data_rev.shape)
data_rev.head()
# Out:
# (64295, 5)
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive            1.000000                0.533333
# 1  Positive            0.250000                0.288462
# 2       NaN            0.182146                0.492704
# 3  Positive            0.400000                0.875000
# 4  Positive            1.000000                0.300000

# %%
import glob

read_files = glob.glob(r'/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/資料/*.csv')

print(read_files)

arrange_data = []
for line in read_files:
    line = line.split('/') # 將每句最後的 \t 取代成空值後，再以逗號斷句
    arrange_data.append(line)
arrange_data

    
df = pd.DataFrame(arrange_data)
df.head()
df_cat = df[10]

print(len(read_files))

df1 = pd.read_csv(read_files[0], sep=',', encoding='utf_8_sig')
c = 0
#看合併後筆數

for f in range(len(read_files)):

    df1= pd.read_csv(read_files[f], sep=',', encoding='utf_8_sig')

#     print(df1["Category"])

    App_name = df1['App']
    App_name


    df_inner=pd.merge(data_rev,df1,how='inner')
    df_inner.head()
    df_inner.shape


    b = data_rev[data_rev.App.isin(df1.App)]
    b = b.reset_index(drop = True)
    print(b["App"].head(3))
    c += len(b)

    b.to_csv('/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/NLP_data/' + df_cat[f], index = False)
print('length: %s' % c)
#         b.to_csv()
# df1["Category"]
# data_path2 = os.path.join(dir_path2, 'ART_AND_DESIGN.csv')
# data_AnD = pd.read_csv(data_path2)
# print(data_AnD.shape)
# data_AnD.head()
# Out:
# ['/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/資料/PARENTING.csv', '/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/資料/HEALTH_AND_FITNESS.csv', '/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/資料/VIDEO_PLAYERS.csv', '/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/資料/EDUCATION.csv', '/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/資料/NEWS_AND_MAGAZINES.csv', '/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/資料/SOCIAL.csv', '/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/資料/FINANCE.csv', '/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/資料/ART_AND_DESIGN.csv', '/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/資料/PERSONALIZATION.csv', '/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/資料/HOUSE_AND_HOME.csv', '/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/資料/LIFESTYLE.csv', '/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data
# ...

# %%
App_name = df1['App']
App_name

# AnD_rev_name = []
# AnD_rev_cont = []

# for i in range(len(data_AnD)):
#     if App_name[i] in data_rev["App"]:
#         AnD_rev_name.append(App_name[i])
#         AnD_rev_cont.append(data_rev["Translated_Review"])
# AnD_rev_name
# AnD_rev_cont
# # App_data.shape
# Out:
# 0                                            Baby Names
# 1                                         My baby Piano
# 2                      Zoo For Preschool Kids 3-9 Years
# 3                           My baby Game (Balloon POP!)
# 4                                      Arabic Alphabets
# 5                           Learn the letters and words
# 6                 Development of the child up to a year
# 7                             Favorite children's songs
# 8                   Ali Baba's Farm Tutorial Kids Games
# 9                              Baby Panda Learns Shapes
# 10                        Learning English for children
# 11                                    Mozart Baby Sleep
# 12                                          Kids Videos
# 13                                     My baby firework
# 14           We learn children's verses in kindergarten
# 15                         Baby Food - Homemade Recipes
# 16                                        My baby Phone
# ...

# %%
# a = []
# for i in range(len(data_AnD)):
#     Art = data_rev['App'] == App_name[i]
#     Art_idx = np.where(Art)[0]
    
#     ART_AND_DESIGN = data_rev.loc[Art_idx]
#     a.append(ART_AND_DESIGN)
# #     ART_AND_DESIGN.to_csv('/Users/jianweicheng/Desktop/ＮＴＵＴ/碩一下/3-2 CRM/期末報告/google_data/NLP_data/' + data_AnD[i] + '.csv', index = False)
# ART_AND_DESIGN.head()
# a = pd.DataFrame(a)
# a

# %%
df_inner=pd.merge(data_rev,df1,how='inner')
df_inner.head()
df_inner.shape
# df_inner['Category']
# Out:
# (10540, 17)

# %%
b = data_rev[data_rev.App.isin(df1.App)]
b = b.reset_index(drop = True)
b
# Out:
#                                    App  \
# 0      1LINE – One Line with One Touch
# 1      1LINE – One Line with One Touch
# 2      1LINE – One Line with One Touch
# 3      1LINE – One Line with One Touch
# 4      1LINE – One Line with One Touch
# 5      1LINE – One Line with One Touch
# 6      1LINE – One Line with One Touch
# 7      1LINE – One Line with One Touch
# 8      1LINE – One Line with One Touch
# 9      1LINE – One Line with One Touch
# 10     1LINE – One Line with One Touch
# 11     1LINE – One Line with One Touch
# 12     1LINE – One Line with One Touch
# 13     1LINE – One Line with One Touch
# 14     1LINE – One Line with One Touch
# 15     1LINE – One Line with One Touch
# 16     1LINE – One Line with One Touch
# 17     1LINE – One Line with One Touch
# 18     1LINE – One Line with One Touch
# 19     1LINE – One Line with One Touch
# 20     1LINE – One Line with One Touch
# 21     1LINE – One Line with One Touch
# 22     1LINE – One Line with One Touch
# ...

# %%
# Out:
# {}
